# %% [markdown]
# [![pythonista.io](img/pythonista.png)](https://www.pythonista.io)

# %% [markdown]
# # Terraform: fundamentos y estado remoto.
#
# Esta sesion se apoya en la misma logica de workflows reutilizables y pipelines declarativos: la infraestructura tambien debe describirse como codigo y validarse antes de tocar recursos reales.
#
# ## Objetivos.
#
# - Entender provider, variables, outputs y modulos.
# - Introducir backend remoto y locking.
# - Preparar la integracion con GitHub Actions.

# %% [markdown]
# ## Terraform dentro del pipeline.
#
# Los comandos `terraform fmt`, `terraform validate` y `terraform plan` son equivalentes de infraestructura a los quality gates vistos antes. Antes de aplicar cambios, el pipeline debe validar sintaxis, consistencia y plan resultante.
#
# El estado remoto importa porque varios operadores o workflows pueden intentar trabajar sobre la misma infraestructura. Sin backend compartido y locking, el riesgo operacional crece de inmediato.

# %%
comandos = ['terraform fmt', 'terraform validate', 'terraform plan']

for comando in comandos:
    print('ejecutar:', comando)

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2017-2026.</p>
