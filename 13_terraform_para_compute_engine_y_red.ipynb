# %% [markdown]
# [![pythonista.io](img/pythonista.png)](https://www.pythonista.io)

# %% [markdown]
# # Terraform para Compute Engine y red.
#
# Esta sesion traslada el enfoque de despliegue seguro a infraestructura mas cercana a Linux tradicional: VM, red, reglas de firewall y base para endurecimiento posterior.
#
# ## Objetivos.
#
# - Aprovisionar VM, VPC y reglas basicas.
# - Preparar una ruta de despliegue en Linux.
# - Entender que seguridad de red y pipeline deben alinearse.

# %% [markdown]
# ## Base para despliegue en Linux.
#
# Cuando el destino es Compute Engine, el pipeline debe coordinarse con decisiones de red y sistema operativo: reglas de firewall, apertura de puertos, cuentas, acceso SSH y rutas de despliegue.
#
# En Py271 se enfatiza una idea: un despliegue seguro en Linux no empieza al conectarse por SSH; empieza al modelar correctamente la infraestructura que recibira la aplicacion.

# %%
componentes = ['compute_engine', 'vpc', 'subnet', 'firewall']

for componente in componentes:
    print('componente:', componente)

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2017-2026.</p>
