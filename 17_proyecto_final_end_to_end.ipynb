# %% [markdown]
# [![pythonista.io](img/pythonista.png)](https://www.pythonista.io)

# %% [markdown]
# # Proyecto final end to end.
#
# Este cierre integra workflows, quality gates, contenedores, seguridad de cadena de suministro, Terraform, GCP, Google Cloud Functions, Linux y criterios de rollback dentro de Py271.
#
# ## Objetivos.
#
# - Integrar la cadena completa de entrega.
# - Presentar un pipeline defendible tecnicamente.
# - Consolidar seguridad, IaC y despliegue como un solo sistema.

# %% [markdown]
# ## Flujo esperado.
#
# El proyecto final debe demostrar una secuencia completa y defendible:
#
# - lint y tipado;
# - pruebas automatizadas;
# - build y publicacion de imagen o artefacto;
# - escaneo y trazabilidad;
# - plan y apply de infraestructura;
# - despliegue y verificaciones posteriores;
# - observabilidad basica con logs, metricas y reglas de alerta.
#
# ## Rutas de entrega recomendadas.
#
# El cierre del curso puede resolverse por dos rutas complementarias:
#
# - una ruta serverless con Google Cloud Functions para workloads ligeros y orientados a eventos;
# - una ruta de servidor Linux por SSH para servicios persistentes y operacion mas tradicional.
#
# En ambos casos, Artifact Registry debe funcionar como punto de control para versionado, auditoria y promocion de artefactos. El proyecto final debe explicitar que señales operativas se revisan despues del despliegue, que umbrales disparan investigacion y bajo que condicion se ejecuta rollback.
#
# ## Evidencia minima esperada.
#
# La presentacion final deberia incluir:
#
# - un smoke test automatizado;
# - una lista de metricas o logs observados tras el deploy;
# - un criterio de alerta;
# - un procedimiento corto de rollback validado.

# %%
pipeline = ['lint', 'tests', 'build', 'scan', 'sbom', 'plan', 'apply', 'deploy']

print('Pipeline final:', ' -> '.join(pipeline))

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2017-2026.</p>
